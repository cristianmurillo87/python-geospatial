# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
# %matplotlib inline

# %%
Point(-78, 41) # Lon, Lat

# %%
Point(-76, 3)

# %%
# 1. Opening up the CSV with pandas
df = pd.read_csv('powerplants/powerplants.csv', sep=';')
# 2. Create a point using shapely by taking the lat/lon fields
points = df.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
# 3. Original dataframe + geometry => geodataframe
powerplants = gpd.GeoDataFrame(df, geometry=points)
# 4. Indicate the geodataframe the CRS to be used
powerplants.crs = 'epsg:4326'
df.head()
# Out:
#    Plant_Code          Plant_Name           Utility_Na  Utility_ID  \
# 0           2        Bankhead Dam     Alabama Power Co         195
# 1           3               Barry     Alabama Power Co         195
# 2           4  Walter Bouldin Dam     Alabama Power Co         195
# 3           7             Gadsden     Alabama Power Co         195
# 4           9              Copper  El Paso Electric Co        5701
#
#          sector_nam       City      County StateName    Zip  \
# 0  Electric Utility  Northport  Tuscaloosa   Alabama  35476
# 1  Electric Utility      Bucks      Mobile   Alabama  36512
# 2  Electric Utility   Wetumpka      Elmore   Alabama  36092
# 3  Electric Utility    Gadsden      Etowah   Alabama  35903
# 4  Electric Utility    El Paso     El Paso     Texas  79915
#
#              Street_Add  ... Geo_MW  Bat_MW  Other_MW  \
# 0    19001 Lock 17 Road  ...    NaN     NaN       NaN
# 1      North Highway 43  ...    NaN     NaN       NaN
# ...
